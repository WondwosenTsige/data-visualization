# %%
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
accident = sns.load_dataset("car_crashes")
accident
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
y = accident["total"].values
x = accident["not_distracted"].values
z = accident["alcohol"].values

# %%
x
# Out:
# array([18.048, 16.29 , 15.624, 21.056, 10.92 , 10.744,  9.396, 14.094,
#         5.9  , 16.468, 14.82 , 14.35 , 13.005, 12.032, 13.775, 15.229,
#        13.706, 16.692, 14.965, 13.137,  8.875,  7.134, 13.395,  8.448,
#         1.76 , 14.812, 17.976, 13.857, 13.965, 10.092,  9.632, 12.328,
#        10.824, 15.792, 23.661, 13.959, 18.308,  8.576, 17.472, 10.212,
#        22.944, 19.012, 15.99 , 17.654,  9.944, 13.056, 11.049,  8.692,
#        23.086,  5.382, 14.094])

# %%
y
# Out:
# array([18.8, 18.1, 18.6, 22.4, 12. , 13.6, 10.8, 16.2,  5.9, 17.9, 15.6,
#        17.5, 15.3, 12.8, 14.5, 15.7, 17.8, 21.4, 20.5, 15.1, 12.5,  8.2,
#        14.1,  9.6, 17.6, 16.1, 21.4, 14.9, 14.7, 11.6, 11.2, 18.4, 12.3,
#        16.8, 23.9, 14.1, 19.9, 12.8, 18.2, 11.1, 23.9, 19.4, 19.5, 19.4,
#        11.3, 13.6, 12.7, 10.6, 23.8, 13.8, 17.4])

# %%
z
# Out:
# array([ 5.64 ,  4.525,  5.208,  5.824,  3.36 ,  3.808,  3.888,  4.86 ,
#         1.593,  5.191,  3.9  ,  7.175,  4.437,  4.352,  4.205,  3.925,
#         4.272,  4.922,  6.765,  4.53 ,  4.   ,  2.87 ,  3.948,  2.784,
#         5.456,  5.474,  9.416,  5.215,  4.704,  3.48 ,  3.136,  4.968,
#         3.567,  5.208, 10.038,  4.794,  5.771,  3.328,  5.642,  4.218,
#         9.799,  6.402,  5.655,  7.372,  1.808,  4.08 ,  3.429,  3.498,
#         6.664,  4.554,  5.568])

# %%
plt.figure()
plt.plot(y, label='Total crashes', color='blue')
plt.plot(x, label='Non Distracted Drivers', color='green')
plt.plot(z, label='Drivers under alcohol influence', color='red')
plt.legend()
sns.set()
sns.set_style('darkgrid')
sns.set(font='mono')
plt.show()

# %% [markdown]
# ### It looks like the above chart is reverted. ????

# %%
sns.lineplot(x="no_previous", y="total", data=accident)
# Out:
# <AxesSubplot:xlabel='no_previous', ylabel='total'>

# %%
sns.catplot(y="total", x="alcohol", data = accident)
